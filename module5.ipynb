# %% [markdown]
# <html>
# <head>
#     <title>Modern HTML</title>
# </head>
# <body>
#     <h1>Q1 Features of HTML5</h1>
#     <ul>
#         <li>Improved semantic elements</li>
#         <li>New form controls</li>
#         <li>Better support for multimedia</li>
#         <li>Enhanced accessibility features</li>
#         <li>Improved performance and loading times</li>
#         <li>Support for web components</li>
#         <li>New APIs for developers</li>
#     </ul>
#     <h1>
#         Q2 What are HTML Entities? List out 5 commonly used HTML entities
#     </h1>
#     <p>
#         HTML entities are special codes that represent characters that have a special meaning in HTML.
#         They are used to display characters that cannot be typed directly into the HTML code, such as symbols or reserved characters.
#          Here are five commonly used HTML entities:
#         <ul>
#             <li>&amp; - Ampersand</li>
#             <li>&lt; - Lesser than</li>
#             <li>&gt; - Greater than</li>
#             <li>&quot; - Double quote</li>
#             <li>&#39; - Single quote</li>
#         </ul>
#         <p>HTML entities are used to ensure that the characters are displayed correctly in the browser and do not interfere with the HTML code itself.</p>
#         <p>For example, if you want to display the less than symbol (<) in your HTML code, you would use the entity &lt; instead. This prevents the browser from interpreting it as the start of a tag.</p>
#         <p>HTML entities are also useful for displaying special characters that may not be available on the keyboard, such as copyright symbols (©) or registered trademarks (®).</p>
#         <p>In summary, HTML entities are a way to represent special characters in HTML code, allowing for proper display and preventing conflicts with the HTML syntax.</p>
#     </p>
#     <br>
#     <h1>
#         Q3 Define accessibility in the context of web development. Discuss why it's essential to create accessible
# websites and how it benefits different user groups?
#     </h1>
#     <p>Accessibility in web development refers to the practice of designing and developing websites that can be used by people with disabilities.
#         This includes individuals with visual, auditory, motor, or cognitive impairments.
#         The goal of accessibility is to ensure that all users, regardless of their abilities, can access and interact with web content effectively.</p>
#     <p>Creating accessible websites is essential for several reasons:</p>
#     <ul>
#         <li><strong>Inclusivity:</strong> Accessibility ensures that everyone, including people with disabilities, can access and benefit from online information and services.</li>
#         <li><strong>Legal Compliance:</strong> Many countries have laws and regulations that require websites to be accessible. Non-compliance can lead to legal consequences.</li>
#         <li><strong>Improved User Experience:</strong> Accessible design often leads to a better overall user experience for all users, not just those with disabilities.</li>
#         <li><strong>Wider Audience Reach:</strong> By making websites accessible, businesses can reach a larger audience, including older adults and individuals with temporary impairments.</li>
#         <li><strong>SEO Benefits:</strong> Accessible websites often rank better in search engines due to improved structure and semantic markup.</li>
#     </ul>
#     <br>
#     <h1>
#         Q4 List any 3 ways which help us in improving the accessibility of HTML?
#     </h1>
#     <p>There are several ways to improve the accessibility of HTML content. Here are three key methods:</p>
#     <ul>
#         <li><strong>Use Semantic HTML:</strong> Utilize semantic elements (e.g., <code>&lt;header&gt;</code>, <code>&lt;nav&gt;</code>, <code>&lt;article&gt;</code>, <code>&lt;footer&gt;</code>) to provide meaning and structure to the content.
#              This helps screen readers and assistive technologies understand the layout and purpose of different sections.</li>
#         <li><strong>Provide Alternative Text for Images:</strong> Use the <code>alt</code> attribute for images to provide descriptive text that conveys the content or function of the image. This is crucial for users who rely on screen readers.</li>
#         <li><strong>Ensure Keyboard Navigation:</strong> Make sure that all interactive elements (e.g., links, buttons, forms) can be accessed and operated using a keyboard alone. This is essential for users with mobility impairments who may not be able to use a mouse.</li>
#     </ul>
#     <br>
#     <h1>
#         Q6 Create a simple web page which has a table. The table must have 2 columns HTML and HTML5. The table
# should include a minimum of three rows describing the differences between HTML and HTML5.
#     </h1>
#     <table border=""1" cellpadding="5">
#     <tr>
#         <td>HTML</td>
#         <td>HTML5</td>
#     </tr>
#     <tr>
#         <td>HTML is a markup language used for creating web pages.</td>
#         <td>HTML5 is the latest version of HTML, which includes new features and improvements.</td>
#     </tr>
#     <tr>
#         <td>HTML does not support audio and video elements directly.</td>
#         <td>HTML5 introduces native support for audio and video elements, making it easier to embed multimedia content.</td>
#         </tr>
#     <tr>
#             <td>
#         HTML requires the use of plugins (e.g., Flash) for multimedia.</td>
#         <td>HTML5 eliminates the need for plugins by providing native support for multimedia elements.</td>
#     </tr>
#     <tr>
#             <td>HTML does not have built-in support for local storage.</td>
#             <td>HTML5 introduces local storage, allowing web applications to store data on the user's device.</td>
#     </tr>
#     <tr>
#             <td>HTML does not support new form elements.</td>
#             <td>HTML5 introduces new form elements such as <code>&lt;input type ="e-mail"&gt;</code>, <code>&lt;input type ="date"&gt;</code>, and <code>&lt;input type ="date"&gt;</code>
#                 0for better user input.</td>
#     </tr>
#     </table>
#
#
# </body>
# </html>

# %% [markdown]
# Ques-5
# <html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Feature of HTML5</title>
#     <link rel="stylesheet" href="style.css">
# </head>
# <BODY>
#     <header>
#         <h1>Features of HTML5</h1>
#     </header>
#     <nav>
#         <ul>
#             <li><a href="#introduction">Introduction</a></li>
#             <li><a href="#features">Key Features</a></li>
#             <li><a href="#conclusion">Conclusion</a></li>
#         </ul>
#     </nav>
#     <main>
#         <section id="features">
#             <h2>Key Features</h2>
#             <ul>
#                 <li><strong>New Elements:</strong> HTML5 introduces new semantic elements like <code>&lt;header&gt;</code>, <code>&lt;footer&gt;</code>, <code>&lt;article&gt;</code>, and <code>&lt;section&gt;</code>.</li>
#                 <li><strong>Audio and Video Support:</strong> HTML5 provides native support for audio and video embedding without the need for plugins.</li>
#                 <li><strong>Canvas Element:</strong> The <code>&lt;canvas&gt;</code> element allows for dynamic, scriptable rendering of 2D shapes and bitmap images.</li>
#                 <li><strong>Local Storage:</strong> HTML5 offers local storage capabilities, allowing web applications to store data locally within the user's browser.</li>
#                 <li><strong>Geolocation API:</strong> This feature allows web applications to access the geographical location of a user.</li>
#             </ul>
#         </section>
#         <figure>
#         <img src="https://i.pinimg.com/736x/50/1b/df/501bdf131e39f1f44c62f72006622ce4.jpg" alt="HTML5 Features" width="400"height="300">
#         <figcaption>HTML5 Features</figcaption>
#         </figure>
#         <article>
#             <p>
#                 HTML5 is the latest version of the <mark>Hypertext Markup Language</mark>,
#                  which is the standard language for creating web pages.
#                  It introduces new features and improvements that enhance the functionality and usability of web applications.
#                   Some of the key features include new semantic elements, audio and video support, the canvas element for graphics, local storage capabilities, and the geolocation API. These advancements make HTML5 a powerful tool for developers and a better experience for users.
#             </p>
#             <aside>
#                 <h3>Additional Resources</h3>
#                 <ul>
#                     <li>
#                         <a href="https://www.w3schools.com/html/html5_intro.asp">W3Schools HTML5 Introduction</a>
#                     </li>
#                     <li>
#                         <a href="https://developer.mozilla.org/en-US/docs/Web/Guide/HTML/HTML5">MDN Web Docs - HTML5 Guide</a>
#                     </li>
#
#                 </ul>
#             </aside>
#
#         </article>
#         <summary>
#             <h2>Conclusion</h2>
#             <p>HTML5 is a significant advancement in web development, providing new features that enhance the user experience and improve the capabilities of web applications.</p>
#         </summary>
#         <footer>
#             <p>&copy; 2023 HTML5 Features. All rights reserved.</p>
#             <p>Contact: <a href="mailto:aman97002@gmail.com">Aman Srivastava</a></p>
#         </footer>
#     </main>
# </BODY>
# </html>
